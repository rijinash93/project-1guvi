# %%
import pandas as pd

# %%
df=pd.read_csv("traffic.csv")
# Out:
# C:\Users\EliteBook\AppData\Local\Temp\ipykernel_16700\155682070.py:1: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv("traffic.csv")

# %%
df
# Out:
#         stop_date stop_time country_name driver_gender  driver_age_raw  \
# 0      2020-01-01   0:00:00       Canada             M              59
# 1      2020-01-01   0:01:00        India             M              35
# 2      2020-01-01   0:02:00          USA             M              26
# 3      2020-01-01   0:03:00       Canada             M              26
# 4      2020-01-01   0:04:00       Canada             M              62
# ...           ...       ...          ...           ...             ...
# 65533  2020-02-15  12:13:00        India             F              54
# 65534  2020-02-15  12:14:00       Canada             F              18
# 65535  2020-02-15  12:15:00          USA             M              27
# 65536  2020-02-15  12:16:00       Canada             F              49
# 65537  2020-02-15  12:17:00          USA             F              72
#
#        driver_age driver_race     violation_raw violation  search_conducted  \
# 0              19       Asian     Drunk Driving  Speeding              True
# 1              58       Other             Other     Other             False
# 2              76       Black  Signal Violation  Speeding             False
# 3              76       Black          Speeding       DUI              True
# 4              75       Other          Speeding     Other             False
# ...           ...         ...               ...       ...               ...
# 65533          48       Black             Other     Other             False
# 65534          35    Hispanic          Seatbelt     Other              True
# 65535          41       Asian          Seatbelt       DUI              True
# 65536          63       Black          Seatbelt     Other             False
# 65537          32       Other          Seatbelt  Speeding              True
#
#           search_type stop_outcome  is_arrested stop_duration  \
# 0      Vehicle Search       Ticket         True     16-30 Min
# 1      Vehicle Search       Arrest         True     16-30 Min
# 2               Frisk       Ticket         True     16-30 Min
# 3               Frisk      Warning        False      0-15 Min
# 4      Vehicle Search       Arrest         True     16-30 Min
# ...               ...          ...          ...           ...
# 65533  Vehicle Search       Arrest         True     16-30 Min
# 65534  Vehicle Search       Ticket        False     16-30 Min
# 65535           Frisk       Ticket         True       30+ Min
# 65536             NaN      Warning         True      0-15 Min
# 65537             NaN       Ticket         True     16-30 Min
#
#        drugs_related_stop vehicle_number
# 0                    True     UP76DY3473
# 1                    True     RJ83PZ4441
# 2                    True     RJ32OM7264
# 3                    True     RJ76TI3807
# 4                   False     WB63BB8305
# ...                   ...            ...
# 65533               False     DL56GW6568
# 65534                True     TN73EO7098
# 65535                True     GJ33MX8328
# 65536                True     KA24UZ8488
# 65537               False     UP89PT2924
#
# [65538 rows x 16 columns]

# %%
df[df.isna().any(axis=1)]
# Out:
#         stop_date stop_time country_name driver_gender  driver_age_raw  \
# 7      2020-01-01   0:07:00        India             M              72
# 9      2020-01-01   0:09:00          USA             M              43
# 10     2020-01-01   0:10:00        India             F              66
# 13     2020-01-01   0:13:00          USA             M              55
# 14     2020-01-01   0:14:00        India             M              44
# ...           ...       ...          ...           ...             ...
# 65523  2020-02-15  12:03:00        India             F              61
# 65529  2020-02-15  12:09:00        India             F              63
# 65530  2020-02-15  12:10:00        India             M              34
# 65536  2020-02-15  12:16:00       Canada             F              49
# 65537  2020-02-15  12:17:00          USA             F              72
#
#        driver_age driver_race     violation_raw violation  search_conducted  \
# 7              50       Asian     Drunk Driving     Other             False
# 9              21       Asian  Signal Violation    Signal              True
# 10             76       Black          Speeding    Signal             False
# 13             58       Black          Seatbelt       DUI             False
# 14             25       Black          Seatbelt       DUI             False
# ...           ...         ...               ...       ...               ...
# 65523          42       Other  Signal Violation     Other              True
# 65529          78       Black          Seatbelt  Seatbelt              True
# 65530          72       White  Signal Violation  Seatbelt              True
# 65536          63       Black          Seatbelt     Other             False
# 65537          32       Other          Seatbelt  Speeding              True
#
#       search_type stop_outcome  is_arrested stop_duration  drugs_related_stop  \
# 7             NaN       Arrest         True       30+ Min                True
# 9             NaN      Warning         True     16-30 Min               False
# 10            NaN       Ticket        False       30+ Min                True
# 13            NaN       Arrest         True       30+ Min               False
# 14            NaN       Arrest         True       30+ Min               False
# ...           ...          ...          ...           ...                 ...
# 65523         NaN       Arrest        False       30+ Min                True
# 65529         NaN      Warning        False      0-15 Min               False
# 65530         NaN       Ticket         True       30+ Min               False
# 65536         NaN      Warning         True      0-15 Min                True
# 65537         NaN       Ticket         True     16-30 Min               False
#
#       vehicle_number
# 7         DL75KZ7835
# 9         KA79RD2271
# 10        UP67CQ9426
# 13        WB56XQ8946
# 14        GJ67CO6825
# ...              ...
# 65523     MH95JU7570
# 65529     DL13IZ8119
# 65530     KA65MU9353
# 65536     KA24UZ8488
# 65537     UP89PT2924
#
# [21720 rows x 16 columns]

# %%
df= df.fillna("")

# %%
df
# Out:
#         stop_date stop_time country_name driver_gender  driver_age_raw  \
# 0      2020-01-01   0:00:00       Canada             M              59
# 1      2020-01-01   0:01:00        India             M              35
# 2      2020-01-01   0:02:00          USA             M              26
# 3      2020-01-01   0:03:00       Canada             M              26
# 4      2020-01-01   0:04:00       Canada             M              62
# ...           ...       ...          ...           ...             ...
# 65533  2020-02-15  12:13:00        India             F              54
# 65534  2020-02-15  12:14:00       Canada             F              18
# 65535  2020-02-15  12:15:00          USA             M              27
# 65536  2020-02-15  12:16:00       Canada             F              49
# 65537  2020-02-15  12:17:00          USA             F              72
#
#        driver_age driver_race     violation_raw violation  search_conducted  \
# 0              19       Asian     Drunk Driving  Speeding              True
# 1              58       Other             Other     Other             False
# 2              76       Black  Signal Violation  Speeding             False
# 3              76       Black          Speeding       DUI              True
# 4              75       Other          Speeding     Other             False
# ...           ...         ...               ...       ...               ...
# 65533          48       Black             Other     Other             False
# 65534          35    Hispanic          Seatbelt     Other              True
# 65535          41       Asian          Seatbelt       DUI              True
# 65536          63       Black          Seatbelt     Other             False
# 65537          32       Other          Seatbelt  Speeding              True
#
#           search_type stop_outcome  is_arrested stop_duration  \
# 0      Vehicle Search       Ticket         True     16-30 Min
# 1      Vehicle Search       Arrest         True     16-30 Min
# 2               Frisk       Ticket         True     16-30 Min
# 3               Frisk      Warning        False      0-15 Min
# 4      Vehicle Search       Arrest         True     16-30 Min
# ...               ...          ...          ...           ...
# 65533  Vehicle Search       Arrest         True     16-30 Min
# 65534  Vehicle Search       Ticket        False     16-30 Min
# 65535           Frisk       Ticket         True       30+ Min
# 65536                      Warning         True      0-15 Min
# 65537                       Ticket         True     16-30 Min
#
#        drugs_related_stop vehicle_number
# 0                    True     UP76DY3473
# 1                    True     RJ83PZ4441
# 2                    True     RJ32OM7264
# 3                    True     RJ76TI3807
# 4                   False     WB63BB8305
# ...                   ...            ...
# 65533               False     DL56GW6568
# 65534                True     TN73EO7098
# 65535                True     GJ33MX8328
# 65536                True     KA24UZ8488
# 65537               False     UP89PT2924
#
# [65538 rows x 16 columns]

# %%
df['stop_date'] = pd.to_datetime(df['stop_date']).dt.strftime('%d/%m/%Y')# prompt: replace other in all coolumns as empty string

df = df.replace('other', '', regex=True)

# %%
df = df.replace('Other', '', regex=True)

# %%
df
# Out:
#         stop_date stop_time country_name driver_gender  driver_age_raw  \
# 0      01/01/2020   0:00:00       Canada             M              59
# 1      01/01/2020   0:01:00        India             M              35
# 2      01/01/2020   0:02:00          USA             M              26
# 3      01/01/2020   0:03:00       Canada             M              26
# 4      01/01/2020   0:04:00       Canada             M              62
# ...           ...       ...          ...           ...             ...
# 65533  15/02/2020  12:13:00        India             F              54
# 65534  15/02/2020  12:14:00       Canada             F              18
# 65535  15/02/2020  12:15:00          USA             M              27
# 65536  15/02/2020  12:16:00       Canada             F              49
# 65537  15/02/2020  12:17:00          USA             F              72
#
#        driver_age driver_race     violation_raw violation  search_conducted  \
# 0              19       Asian     Drunk Driving  Speeding              True
# 1              58                                                     False
# 2              76       Black  Signal Violation  Speeding             False
# 3              76       Black          Speeding       DUI              True
# 4              75                      Speeding                       False
# ...           ...         ...               ...       ...               ...
# 65533          48       Black                                         False
# 65534          35    Hispanic          Seatbelt                        True
# 65535          41       Asian          Seatbelt       DUI              True
# 65536          63       Black          Seatbelt                       False
# 65537          32                      Seatbelt  Speeding              True
#
#           search_type stop_outcome  is_arrested stop_duration  \
# 0      Vehicle Search       Ticket         True     16-30 Min
# 1      Vehicle Search       Arrest         True     16-30 Min
# 2               Frisk       Ticket         True     16-30 Min
# 3               Frisk      Warning        False      0-15 Min
# 4      Vehicle Search       Arrest         True     16-30 Min
# ...               ...          ...          ...           ...
# 65533  Vehicle Search       Arrest         True     16-30 Min
# 65534  Vehicle Search       Ticket        False     16-30 Min
# 65535           Frisk       Ticket         True       30+ Min
# 65536                      Warning         True      0-15 Min
# 65537                       Ticket         True     16-30 Min
#
#        drugs_related_stop vehicle_number
# 0                    True     UP76DY3473
# 1                    True     RJ83PZ4441
# 2                    True     RJ32OM7264
# 3                    True     RJ76TI3807
# 4                   False     WB63BB8305
# ...                   ...            ...
# 65533               False     DL56GW6568
# 65534                True     TN73EO7098
# 65535                True     GJ33MX8328
# 65536                True     KA24UZ8488
# 65537               False     UP89PT2924
#
# [65538 rows x 16 columns]

# %%
db_url = "postgresql+pg8000://rijina3030:sOg4cFE5Nguj0kiXk0h86gQjVNPcbJy4@dpg-d0krorbe5dus73c1qhsg-a.singapore-postgres.render.com/project1"

# %%
pip install pg8000
# Out:
# Requirement already satisfied: pg8000 in c:\users\elitebook\appdata\local\programs\python\python38\lib\site-packages (1.31.2)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\elitebook\appdata\roaming\python\python38\site-packages (from pg8000) (2.8.2)
# Requirement already satisfied: scramp>=1.4.5 in c:\users\elitebook\appdata\local\programs\python\python38\lib\site-packages (from pg8000) (1.4.5)
# Requirement already satisfied: six>=1.5 in c:\users\elitebook\appdata\local\programs\python\python38\lib\site-packages (from python-dateutil>=2.8.2->pg8000) (1.16.0)
# Requirement already satisfied: asn1crypto>=1.5.1 in c:\users\elitebook\appdata\local\programs\python\python38\lib\site-packages (from scramp>=1.4.5->pg8000) (1.5.1)

# %%
from sqlalchemy import create_engine, inspect
engine=create_engine(db_url)

# %%
Query="select * from traffic";
df=pd.read_sql(Query,engine)

# %%
df
# Out:
#         stop_date stop_time country_name driver_gender  driver_age_raw  \
# 0      01/01/2020   0:00:00       Canada             M              59
# 1      01/01/2020   0:01:00        India             M              35
# 2      01/01/2020   0:02:00          USA             M              26
# 3      01/01/2020   0:03:00       Canada             M              26
# 4      01/01/2020   0:04:00       Canada             M              62
# ...           ...       ...          ...           ...             ...
# 65533  15/02/2020  12:13:00        India             F              54
# 65534  15/02/2020  12:14:00       Canada             F              18
# 65535  15/02/2020  12:15:00          USA             M              27
# 65536  15/02/2020  12:16:00       Canada             F              49
# 65537  15/02/2020  12:17:00          USA             F              72
#
#        driver_age driver_race     violation_raw violation  search_conducted  \
# 0              19       Asian     Drunk Driving  Speeding              True
# 1              58        None              None      None             False
# 2              76       Black  Signal Violation  Speeding             False
# 3              76       Black          Speeding       DUI              True
# 4              75        None          Speeding      None             False
# ...           ...         ...               ...       ...               ...
# 65533          48       Black              None      None             False
# 65534          35    Hispanic          Seatbelt      None              True
# 65535          41       Asian          Seatbelt       DUI              True
# 65536          63       Black          Seatbelt      None             False
# 65537          32        None          Seatbelt  Speeding              True
#
#           search_type stop_outcome  is_arrested stop_duration  \
# 0      Vehicle Search       Ticket         True     16-30 Min
# 1      Vehicle Search       Arrest         True     16-30 Min
# 2               Frisk       Ticket         True     16-30 Min
# 3               Frisk      Warning        False      0-15 Min
# 4      Vehicle Search       Arrest         True     16-30 Min
# ...               ...          ...          ...           ...
# 65533  Vehicle Search       Arrest         True     16-30 Min
# 65534  Vehicle Search       Ticket        False     16-30 Min
# 65535           Frisk       Ticket         True       30+ Min
# 65536            None      Warning         True      0-15 Min
# 65537            None       Ticket         True     16-30 Min
#
#        drugs_related_stop vehicle_number
# 0                    True     UP76DY3473
# 1                    True     RJ83PZ4441
# 2                    True     RJ32OM7264
# 3                    True     RJ76TI3807
# 4                   False     WB63BB8305
# ...                   ...            ...
# 65533               False     DL56GW6568
# 65534                True     TN73EO7098
# 65535                True     GJ33MX8328
# 65536                True     KA24UZ8488
# 65537               False     UP89PT2924
#
# [65538 rows x 16 columns]

# %%
print(df.dtypes)
# Out:
# stop_date             object
# stop_time             object
# country_name          object
# driver_gender         object
# driver_age_raw         int64
# driver_age             int64
# driver_race           object
# violation_raw         object
# violation             object
# search_conducted        bool
# search_type           object
# stop_outcome          object
# is_arrested             bool
# stop_duration         object
# drugs_related_stop      bool
# vehicle_number        object
# dtype: object

# %%
empty_cols = df.columns[df.isna().all()]
print("Empty columns:", empty_cols)
# Out:
# Empty columns: Index([], dtype='object')

# %%
df_cleaned = df.dropna(axis=0, how='any')

# %%
df_cleaned
# Out:
#         stop_date stop_time country_name driver_gender  driver_age_raw  \
# 0      01/01/2020   0:00:00       Canada             M              59
# 2      01/01/2020   0:02:00          USA             M              26
# 3      01/01/2020   0:03:00       Canada             M              26
# 6      01/01/2020   0:06:00          USA             F              80
# 11     01/01/2020   0:11:00       Canada             F              58
# ...           ...       ...          ...           ...             ...
# 65525  15/02/2020  12:05:00       Canada             F              74
# 65527  15/02/2020  12:07:00        India             M              74
# 65528  15/02/2020  12:08:00          USA             M              32
# 65531  15/02/2020  12:11:00        India             M              47
# 65535  15/02/2020  12:15:00          USA             M              27
#
#        driver_age driver_race     violation_raw violation  search_conducted  \
# 0              19       Asian     Drunk Driving  Speeding              True
# 2              76       Black  Signal Violation  Speeding             False
# 3              76       Black          Speeding       DUI              True
# 6              70       White  Signal Violation  Speeding             False
# 11             53    Hispanic  Signal Violation    Signal             False
# ...           ...         ...               ...       ...               ...
# 65525          61    Hispanic          Seatbelt  Seatbelt              True
# 65527          23       White     Drunk Driving  Seatbelt              True
# 65528          37       White          Seatbelt       DUI              True
# 65531          70    Hispanic          Seatbelt    Signal             False
# 65535          41       Asian          Seatbelt       DUI              True
#
#           search_type stop_outcome  is_arrested stop_duration  \
# 0      Vehicle Search       Ticket         True     16-30 Min
# 2               Frisk       Ticket         True     16-30 Min
# 3               Frisk      Warning        False      0-15 Min
# 6      Vehicle Search       Ticket        False       30+ Min
# 11     Vehicle Search       Arrest         True       30+ Min
# ...               ...          ...          ...           ...
# 65525           Frisk       Ticket        False     16-30 Min
# 65527           Frisk      Warning        False     16-30 Min
# 65528           Frisk       Arrest         True       30+ Min
# 65531  Vehicle Search       Ticket         True     16-30 Min
# 65535           Frisk       Ticket         True       30+ Min
#
#        drugs_related_stop vehicle_number
# 0                    True     UP76DY3473
# 2                    True     RJ32OM7264
# 3                    True     RJ76TI3807
# 6                   False     KA40AD3153
# 11                   True     KA61JB1004
# ...                   ...            ...
# 65525               False     GJ41TB4105
# 65527                True     UP13ZV9824
# 65528               False     MH85WS4348
# 65531                True     WB25SO5088
# 65535                True     GJ33MX8328
#
# [22474 rows x 16 columns]

# %%
df.isna().any().any()
# Out:
# True

# %%
df_cleaned.isna().any().any()
# Out:
# False

# %%
pip install files
# Out:
# Requirement already satisfied: files in c:\users\elitebook\appdata\local\programs\python\python38\lib\site-packages (1.1.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import files

df_cleaned.to_csv('cleaned_traffic_data.csv', index=False)

# %%
db_url = "postgresql+pg8000://rijina3030:sOg4cFE5Nguj0kiXk0h86gQjVNPcbJy4@dpg-d0krorbe5dus73c1qhsg-a.singapore-postgres.render.com/project1"

# %%
from sqlalchemy import create_engine, inspect
engine=create_engine(db_url)

# %%
df_cleaned.to_sql('traffic_stops',engine,index=False,if_exists='replace')
